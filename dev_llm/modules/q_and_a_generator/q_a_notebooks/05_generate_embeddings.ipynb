# %%
import sys

sys.path.append('/Projects/regionintelligenceai/dev_llm/modules/q_and_a_generator/')


import os
from typing import List, Dict, Tuple, Optional
import hashlib
from pydantic import BaseModel
from unstructured.partition.html import partition_html
from unstructured.cleaners.core import clean, replace_unicode_quotes, clean_non_ascii_chars
from unstructured.staging.huggingface import chunk_by_attention_window
from unstructured.staging.huggingface import stage_for_transformers
from transformers import AutoTokenizer, AutoModel
from tqdm import tqdm

from src.paths import JSON_DATA_DIR
from src.logger import get_console_logger

import dotenv
dotenv.load_dotenv()

QDRANT_API_KEY = os.environ.get('QDRANT_API_KEY')
QDRANT_API_URL = os.environ.get('QDRANT_API_URL')

CALIFORNIA_JSON_FILE = JSON_DATA_DIR / 'california_building_codes_json' / 'california_20231015.json'
QDRANT_COLLECTION_NAME = 'california_building_codes'
QDRANT_VECTOR_SIZE = 384

# %%
# init logger
logger = get_console_logger()

# tokenizer and LLM we use to embed the document text
tokenizer = AutoTokenizer.from_pretrained("sentence-transformers/all-MiniLM-L6-v2")
model = AutoModel.from_pretrained("sentence-transformers/all-MiniLM-L6-v2")

# init qdrant client and collection where we store the news
from src.vector_db_api import get_qdrant_client, init_collection
qdrant_client = get_qdrant_client()
qdrant_client = init_collection(
    qdrant_client=qdrant_client,
    collection_name=QDRANT_COLLECTION_NAME,
    vector_size=QDRANT_VECTOR_SIZE,
)

class Document(BaseModel):
    id: str
    group_key: Optional[str] = None
    metadata: Optional[dict] = {}
    text: Optional[list] = []
    chunks: Optional[list] = []
    embeddings: Optional[list] = []

def parse_document(chapter_data: Dict) -> Document:
    try:
        document_id = hashlib.md5(str(chapter_data).encode()).hexdigest()
        document = Document(id=document_id)
        texts = []

        for section in chapter_data['sections']:
            texts.append(section['title'])
            texts.append(section['content'])
            for subsection in section['subsections']:
                texts.append(subsection['title'])
                texts.append(subsection['content'])

        joined_text = " ".join(texts)
        document.text = [joined_text]
        document.metadata['chapter'] = chapter_data['chapter']
        
        return document
    except Exception as e:
        logger.error(f"Error parsing document: {e}")
        return None
    
def chunk(document: Document) -> Document:
    try:
        chunks = []
        for text in document.text:
            chunks += chunk_by_attention_window(
                text, tokenizer, max_input_size=QDRANT_VECTOR_SIZE)
        
        document.chunks = chunks
        return document
    except Exception as e:
        logger.error(f"Error chunking document: {e}")
        return None

def embedding(document: Document) -> Document:
    try:
        for chunk in document.text:
            inputs = tokenizer(chunk,
                               padding=True,
                               truncation=True,
                               return_tensors="pt",
                               max_length=QDRANT_VECTOR_SIZE)

            result = model(**inputs)
            embeddings = result.last_hidden_state[:, 0, :].cpu().detach().numpy()
            lst = embeddings.flatten().tolist()
            document.embeddings.append(lst)
        return document
    except Exception as e:
        logger.error(f"Error while embedding document: {e}")
        return None


def build_payloads(doc: Document) -> List:
    try:
        payloads = []
        for chunk in doc.chunks:
            payload = doc.metadata
            payload.update({"text": chunk})
            payloads.append(payload)
        return payloads
    except Exception as e:
        logger.error(f"Error while building payloads: {e}")
        return []


def push_document_to_qdrant(doc: Document) -> None:
    try:
        from qdrant_client.models import PointStruct

        _payloads = build_payloads(doc)

        qdrant_client.upsert(
            collection_name=QDRANT_COLLECTION_NAME,
            points=[
                PointStruct(
                    id=idx,
                    vector=vector,
                    payload=_payload
                )
                for idx, (vector, _payload) in enumerate(zip(doc.embeddings, _payloads))
            ]
        )
    except Exception as e:
        logger.error(f"Error while pushing document to Qdrant: {e}")


def process_one_building_code(_data: Dict) -> None:
    """Process a single building code."""
    try:
        doc = parse_document(_data)
        if doc is None:
            return None
        doc = chunk(doc)
        if doc is None:
            return None
        doc = embedding(doc)
        if doc is None:
            return None
        push_document_to_qdrant(doc)

        return doc
    except Exception as e:
        logger.error(f"Error while processing building code: {e}")
        return None

def process_one_document(_data: Dict) -> None:
    """"""
    try:
        doc = parse_document(_data)
        if doc:
            doc = chunk(doc)
            doc = embedding(doc)
            push_document_to_qdrant(doc)
        return doc
    except Exception as e:
        logger.error(f"Error while processing one building code document: {e}")
        return None
    
def embed_building_codes_into_qdrant(building_codes_data: List[Dict], n_processes: int = 1) -> None:
    """"""
    results = []
    try:
        if n_processes == 1:
            # sequential
            for _data in tqdm(building_codes_data):
                result = process_one_document(_data)
                results.append(result)
        else:
            # parallel
            import multiprocessing

            # Create a multiprocessing Pool
            with multiprocessing.Pool(processes=n_processes) as pool:
                # Use tqdm to create a progress bar
                results = list(tqdm(pool.imap(process_one_document, building_codes_data),
                                    total=len(building_codes_data),
                                    desc="Processing",
                                    unit="building_code"))

        breakpoint()
    except Exception as e:
        logger.error(f"Error while embedding building codes into Qdrant: {e}")

if __name__ == '__main__':
    """"""
    import json
    with open(CALIFORNIA_JSON_FILE, 'r') as json_file:
        building_codes_data = json.load(json_file)

    embed_building_codes_into_qdrant(
        building_codes_data,
        n_processes=1
    )
# Out:
#   3%|▎         | 467/15502 [01:51<39:40,  6.32it/s]  2023-10-18 20:49:40,717 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.00001688}'
#   3%|▎         | 538/15502 [02:09<59:59,  4.16it/s]  2023-10-18 20:49:58,272 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000016415}'
# 2023-10-18 20:49:58,363 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.00001541}'
#   3%|▎         | 540/15502 [02:09<42:37,  5.85it/s]2023-10-18 20:49:58,451 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015436}'
# 2023-10-18 20:49:58,542 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015583}'
#   3%|▎         | 542/15502 [02:09<34:36,  7.21it/s]2023-10-18 20:49:58,630 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.00001488}'
# 2023-10-18 20:49:58,717 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.00001583}'
#   5%|▌         | 841/15502 [03:17<47:06,  5.19it/s]  2023-10-18 20:51:07,085 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000023294}'
#   5%|▌         | 843/15502 [03:18<38:50,  6.29it/s]2023-10-18 20:51:07,316 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015427}'
#   5%|▌         | 845/15502 [03:18<34:33,  7.07it/s]2023-10-18 20:51:07,543 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000019612}'
#  15%|█▍        | 2278/15502 [08:05<23:58,  9.19it/s]  2023-10-18 20:55:54,111 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015986}'
#  15%|█▌        | 2383/15502 [08:23<34:17,  6.37it/s]  2023-10-18 20:56:13,063 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000023233}'
#  16%|█▌        | 2435/15502 [08:32<28:08,  7.74it/s]2023-10-18 20:56:21,209 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015979}'
#  16%|█▌        | 2444/15502 [08:33<37:31,  5.80it/s]2023-10-18 20:56:22,812 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000019419}'
#  16%|█▌        | 2448/15502 [08:34<29:36,  7.35it/s]2023-10-18 20:56:23,277 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015785}'
# 2023-10-18 20:56:23,365 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015902}'
#  16%|█▌        | 2451/15502 [08:34<26:26,  8.23it/s]2023-10-18 20:56:23,595 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015211}'
# 2023-10-18 20:56:23,684 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014756}'
#  16%|█▌        | 2454/15502 [08:34<25:11,  8.63it/s]2023-10-18 20:56:23,912 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000016096}'
# 2023-10-18 20:56:24,002 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.00001828}'
#  16%|█▌        | 2457/15502 [08:35<24:16,  8.96it/s]2023-10-18 20:56:24,226 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015478}'
# 2023-10-18 20:56:24,311 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015458}'
#  16%|█▌        | 2460/15502 [08:35<23:02,  9.44it/s]2023-10-18 20:56:24,520 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015949}'
# 2023-10-18 20:56:24,609 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014857}'
#  16%|█▌        | 2463/15502 [08:35<24:05,  9.02it/s]2023-10-18 20:56:24,852 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014761}'
# 2023-10-18 20:56:24,942 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015885}'
#  16%|█▌        | 2465/15502 [08:35<22:22,  9.71it/s]2023-10-18 20:56:25,036 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014699}'
#  16%|█▌        | 2467/15502 [08:36<22:43,  9.56it/s]2023-10-18 20:56:25,246 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015996}'
# 2023-10-18 20:56:25,335 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014567}'
#  16%|█▌        | 2470/15502 [08:36<23:14,  9.34it/s]2023-10-18 20:56:25,563 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015904}'
# 2023-10-18 20:56:25,651 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014943}'
#  16%|█▌        | 2473/15502 [08:36<24:01,  9.04it/s]2023-10-18 20:56:25,889 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015897}'
# 2023-10-18 20:56:25,976 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015675}'
#  16%|█▌        | 2476/15502 [08:37<23:32,  9.22it/s]2023-10-18 20:56:26,197 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000017426}'
# 2023-10-18 20:56:26,283 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015504}'
#  16%|█▌        | 2479/15502 [08:37<23:36,  9.19it/s]2023-10-18 20:56:26,515 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015432}'
# 2023-10-18 20:56:26,606 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000016535}'
#  16%|█▌        | 2482/15502 [08:37<23:34,  9.20it/s]2023-10-18 20:56:26,827 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014959}'
#  16%|█▌        | 2484/15502 [08:37<23:57,  9.06it/s]2023-10-18 20:56:27,096 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015896}'
#  16%|█▌        | 2485/15502 [08:38<24:51,  8.72it/s]2023-10-18 20:56:27,192 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014613}'
#  16%|█▌        | 2487/15502 [08:38<24:56,  8.69it/s]2023-10-18 20:56:27,493 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015729}'
#  16%|█▌        | 2488/15502 [08:38<27:19,  7.94it/s]2023-10-18 20:56:27,581 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000045835}'
#  16%|█▌        | 2490/15502 [08:38<25:21,  8.55it/s]2023-10-18 20:56:27,788 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.00001763}'
# 2023-10-18 20:56:27,876 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000036135}'
#  16%|█▌        | 2493/15502 [08:38<23:37,  9.18it/s]2023-10-18 20:56:28,080 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000016402}'
# 2023-10-18 20:56:28,180 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000016771}'
#  16%|█▌        | 2503/15502 [08:40<24:35,  8.81it/s]2023-10-18 20:56:29,332 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.00003013}'
#  18%|█▊        | 2758/15502 [09:30<44:49,  4.74it/s]  2023-10-18 20:57:19,523 - tutorial - ERROR - Error chunking document: The number of tokens in the segment is 438. The maximum number of tokens is 382. Consider using a different split_function to reduce the size of the segments under consideration. The text that caused the error is:
#
# RISE
# R
# (feet)
# FAN
# NAT
# FAN
# NAT
# FAN
# NAT
# FAN
# NAT
# FAN
# NAT
# Min
# Max
# Max
# Min
# Max
# Max
# Min
# Max
# Max
# Min
# Max
# Max
# Min
# Max
# Max
# 6
# 1
# 22
# 37
# 26
# 35
# 66
# 46
# 46
# 106
# 72
# 58
# 164
# 104
# 77
# 225
# 142
# 2
# 23
# 41
# 31
# 37
# 75
# 55
# 48
# 121
# 86
# 60
# 183
# 124
# 79
# 253
# 168
# 3
# 24
# 44
# 35
# 38
# 81
# 62
# 49
# 132
# 96
# 62
# 199
# 139
# 82
# 275
# 189
# 8
# 1
# 22
# 40
# 27
# 35
# 72
# 48
# 49
# 114
# 76
# 64
# 176
# 109
# 84
# 243
# 148
# 2
# 23
# 44
# 32
# 36
# 80
# 57
# 51
# 128
# 90
# 66
# 195
# 129
# 86
# 269
# 175
# 3
# 24
# 47
# 36
# 37
# 87
# 64
# 53
# 139
# 101
# 67
# 210
# 145
# 88
# 290
# 198
# 10
# 1
# 22
# 43
# 28
# 34
# 78
# 50
# 49
# 123
# 78
# 65
# 189
# 113
# 89
# 257
# 154
# 2
# 23
# 47
# 33
# 36
# 86
# 59
# 51
# 136
# 93
# 67
# 206
# 134
# 91
# 282
# 182
# 3
# 24
# 50
# 37
# 37
# 92
# 67
# 52
# 146
# 104
# 69
# 220
# 150
# 94
# 303
# 205
# 15
# 1
# 21
# 50
# 30
# 33
# 89
# 53
# 47
# 142
# 83
# 64
# 220
# 120
# 88
# 298
# 163
# 2
# 22
# 53
# 35
# 35
# 96
# 63
# 49
# 153
# 99
# 66
# 235
# 142
# 91
# 320
# 193
# 3
# 24
# 55
# 40
# 36
# 102
# 71
# 51
# 163
# 111
# 68
# 248
# 160
# 93
# 339
# 218
# 20
# 1
# 21
# 54
# 31
# 33
# 99
# 56
# 46
# 157
# 87
# 62
# 246
# 125
# 86
# 334
# 171
# 2
# 22
# 57
# 37
# 34
# 105
# 66
# 48
# 167
# 104
# 64
# 259
# 149
# 89
# 354
# 202
# 3
# 23
# 60
# 42
# 35
# 110
# 74
# 50
# 176
# 116
# 66
# 271
# 168
# 91
# 371
# 228
# 30
# 1
# 20
# 62
# 33
# 31
# 113
# 59
# 45
# 181
# 93
# 60
# 288
# 134
# 83
# 391
# 182
# 2
# 21
# 64
# 39
# 33
# 118
# 70
# 47
# 190
# 110
# 62
# 299
# 158
# 85
# 408
# 215
# 3
# 22
# 66
# 44
# 34
# 123
# 79
# 48
# 198
# 124
# 64
# 309
# 178
# 88
# 423
# 242
# 50
# 1
# 19
# 71
# 36
# 30
# 133
# 64
# 43
# 216
# 101
# 57
# 349
# 145
# 78
# 477
# 197
# 2
# 21
# 73
# 43
# 32
# 137
# 76
# 45
# 223
# 119
# 59
# 358
# 172
# 81
# 490
# 234
# 3
# 22
# 75
# 48
# 33
# 141
# 86
# 46
# 229
# 134
# 61
# 366
# 194
# 83
# 502
# 263
# 100
# 1
# 18
# 82
# 37
# 28
# 158
# 66
# 40
# 262
# 104
# 53
# 442
# 150
# 73
# 611
# 204
# 2
# 19
# 83
# 44
# 30
# 161
# 79
# 42
# 267
# 123
# 55
# 447
# 178
# 75
# 619
# 242
# 3
# 20
# 84
# 50
# 31
# 163
# 89
# 44
# 272
# 138
# 57
# 452
# 200
# 78
# 627
# 272
# COMMON
# 2023-10-18 20:57:19,524 - tutorial - ERROR - Error while embedding document: 'NoneType' object has no attribute 'text'
# 2023-10-18 20:57:19,524 - tutorial - ERROR - Error while building payloads: 'NoneType' object has no attribute 'chunks'
# 2023-10-18 20:57:19,525 - tutorial - ERROR - Error while pushing document to Qdrant: 'NoneType' object has no attribute 'embeddings'
#  18%|█▊        | 2778/15502 [09:34<31:56,  6.64it/s]2023-10-18 20:57:23,427 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.00001636}'
#  18%|█▊        | 2788/15502 [09:35<31:01,  6.83it/s]2023-10-18 20:57:24,841 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000016986}'
#  18%|█▊        | 2790/15502 [09:35<27:56,  7.58it/s]2023-10-18 20:57:25,511 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015689}'
#  18%|█▊        | 2792/15502 [09:36<43:41,  4.85it/s]2023-10-18 20:57:25,738 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000016042}'
#  18%|█▊        | 2798/15502 [09:37<40:58,  5.17it/s]2023-10-18 20:57:26,917 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000020887}'
#  18%|█▊        | 2800/15502 [09:38<33:45,  6.27it/s]2023-10-18 20:57:27,193 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000025217}'
#  18%|█▊        | 2802/15502 [09:38<31:34,  6.70it/s]2023-10-18 20:57:27,497 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000024207}'
#  18%|█▊        | 2815/15502 [09:40<32:38,  6.48it/s]2023-10-18 20:57:29,751 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000016253}'
#  18%|█▊        | 2829/15502 [09:42<28:47,  7.34it/s]2023-10-18 20:57:31,650 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000022327}'
#  18%|█▊        | 2838/15502 [09:43<32:05,  6.58it/s]2023-10-18 20:57:32,954 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000017546}'
#  18%|█▊        | 2840/15502 [09:44<29:30,  7.15it/s]2023-10-18 20:57:33,206 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015721}'
#  18%|█▊        | 2842/15502 [09:44<27:45,  7.60it/s]2023-10-18 20:57:33,442 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014585}'
#  18%|█▊        | 2844/15502 [09:44<26:25,  7.98it/s]2023-10-18 20:57:33,670 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015776}'
# 2023-10-18 20:57:33,759 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014885}'
#  18%|█▊        | 2847/15502 [09:44<25:24,  8.30it/s]2023-10-18 20:57:34,002 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000018232}'
# 2023-10-18 20:57:34,093 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000018355}'
#  18%|█▊        | 2850/15502 [09:45<24:30,  8.60it/s]2023-10-18 20:57:34,325 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000017252}'
# 2023-10-18 20:57:34,412 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000017914}'
#  18%|█▊        | 2853/15502 [09:45<23:52,  8.83it/s]2023-10-18 20:57:34,642 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014828}'
# 2023-10-18 20:57:34,737 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015351}'
#  18%|█▊        | 2856/15502 [09:45<23:46,  8.86it/s]2023-10-18 20:57:34,968 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000029841}'
# 2023-10-18 20:57:35,058 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000025673}'
#  21%|██▏       | 3298/15502 [11:03<35:51,  5.67it/s]  2023-10-18 20:58:52,666 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000016983}'
#  21%|██▏       | 3300/15502 [11:03<29:52,  6.81it/s]2023-10-18 20:58:52,890 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000016999}'
#  21%|██▏       | 3302/15502 [11:04<26:44,  7.60it/s]2023-10-18 20:58:53,107 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014357}'
#  21%|██▏       | 3305/15502 [11:04<26:18,  7.73it/s]2023-10-18 20:58:53,479 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000016545}'
#  21%|██▏       | 3307/15502 [11:04<25:07,  8.09it/s]2023-10-18 20:58:53,705 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014876}'
#  22%|██▏       | 3339/15502 [11:11<34:15,  5.92it/s]  2023-10-18 20:59:00,930 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015471}'
#  22%|██▏       | 3341/15502 [11:12<29:06,  6.96it/s]2023-10-18 20:59:01,170 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015194}'
#  22%|██▏       | 3348/15502 [11:13<31:00,  6.53it/s]2023-10-18 20:59:02,294 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000017244}'
#  22%|██▏       | 3363/15502 [11:16<33:50,  5.98it/s]2023-10-18 20:59:05,176 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014748}'
#  22%|██▏       | 3388/15502 [11:20<29:42,  6.80it/s]2023-10-18 20:59:09,100 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.00001632}'
#  22%|██▏       | 3395/15502 [11:20<28:05,  7.18it/s]2023-10-18 20:59:10,051 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.00001528}'
# 2023-10-18 20:59:10,139 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015242}'
#  22%|██▏       | 3398/15502 [11:21<24:41,  8.17it/s]2023-10-18 20:59:10,372 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015164}'
# 2023-10-18 20:59:10,462 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014552}'
#  22%|██▏       | 3401/15502 [11:21<23:48,  8.47it/s]2023-10-18 20:59:10,699 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015878}'
#  22%|██▏       | 3404/15502 [11:21<24:53,  8.10it/s]2023-10-18 20:59:11,078 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000028524}'
#  22%|██▏       | 3406/15502 [11:22<25:09,  8.01it/s]2023-10-18 20:59:11,331 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000016196}'
#  22%|██▏       | 3408/15502 [11:22<25:18,  7.96it/s]2023-10-18 20:59:11,586 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000016286}'
#  22%|██▏       | 3410/15502 [11:22<24:31,  8.22it/s]2023-10-18 20:59:11,811 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015944}'
# 2023-10-18 20:59:11,934 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014612}'
#  22%|██▏       | 3413/15502 [11:23<25:25,  7.92it/s]2023-10-18 20:59:12,205 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015304}'
#  22%|██▏       | 3415/15502 [11:23<32:27,  6.21it/s]2023-10-18 20:59:12,586 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015113}'
# 2023-10-18 20:59:12,675 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000016589}'
#  22%|██▏       | 3417/15502 [11:23<26:37,  7.56it/s]2023-10-18 20:59:12,765 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015424}'
#  22%|██▏       | 3419/15502 [11:23<26:07,  7.71it/s]2023-10-18 20:59:13,026 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000029029}'
# 2023-10-18 20:59:13,119 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015692}'
#  22%|██▏       | 3421/15502 [11:24<23:50,  8.45it/s]2023-10-18 20:59:13,216 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015202}'
#  22%|██▏       | 3423/15502 [11:24<25:03,  8.04it/s]2023-10-18 20:59:13,493 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014946}'
#  22%|██▏       | 3424/15502 [11:24<24:08,  8.34it/s]2023-10-18 20:59:13,583 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015581}'
# 2023-10-18 20:59:13,672 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015534}'
#  22%|██▏       | 3427/15502 [11:24<23:19,  8.63it/s]2023-10-18 20:59:13,905 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014438}'
# 2023-10-18 20:59:13,993 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000027028}'
#  22%|██▏       | 3429/15502 [11:24<21:22,  9.41it/s]2023-10-18 20:59:14,102 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014533}'
#  22%|██▏       | 3431/15502 [11:25<25:45,  7.81it/s]2023-10-18 20:59:14,414 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.00001512}'
#  22%|██▏       | 3432/15502 [11:25<24:59,  8.05it/s]2023-10-18 20:59:14,594 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015419}'
#  22%|██▏       | 3433/15502 [11:25<27:49,  7.23it/s]2023-10-18 20:59:14,713 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000025008}'
#  22%|██▏       | 3434/15502 [11:25<26:48,  7.50it/s]2023-10-18 20:59:14,802 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000016}'
#  22%|██▏       | 3436/15502 [11:25<27:31,  7.31it/s]2023-10-18 20:59:15,098 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000017199}'
#  22%|██▏       | 3437/15502 [11:26<25:51,  7.78it/s]2023-10-18 20:59:15,198 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015656}'
# 2023-10-18 20:59:15,297 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015952}'
#  22%|██▏       | 3440/15502 [11:26<27:15,  7.38it/s]2023-10-18 20:59:15,605 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014997}'
#  22%|██▏       | 3441/15502 [11:26<25:51,  7.77it/s]2023-10-18 20:59:15,702 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015543}'
# 2023-10-18 20:59:15,800 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.0000155}'
#  22%|██▏       | 3443/15502 [11:26<23:18,  8.62it/s]2023-10-18 20:59:15,899 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014852}'
#  22%|██▏       | 3445/15502 [11:27<25:40,  7.82it/s]2023-10-18 20:59:16,193 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015288}'
# 2023-10-18 20:59:16,287 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000016498}'
#  22%|██▏       | 3447/15502 [11:27<23:25,  8.58it/s]2023-10-18 20:59:16,377 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000046757}'
# 2023-10-18 20:59:16,469 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000016324}'
#  22%|██▏       | 3450/15502 [11:27<22:50,  8.80it/s]2023-10-18 20:59:16,701 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000024342}'
# 2023-10-18 20:59:16,795 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015243}'
#  22%|██▏       | 3452/15502 [11:27<21:28,  9.35it/s]2023-10-18 20:59:16,896 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015482}'
#  22%|██▏       | 3453/15502 [11:27<21:14,  9.45it/s]2023-10-18 20:59:16,995 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014112}'
#  22%|██▏       | 3455/15502 [11:28<22:40,  8.85it/s]2023-10-18 20:59:17,235 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014783}'
# 2023-10-18 20:59:17,397 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.00001526}'
#  22%|██▏       | 3457/15502 [11:28<23:27,  8.56it/s]2023-10-18 20:59:17,497 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000016541}'
#  22%|██▏       | 3458/15502 [11:28<22:47,  8.81it/s]2023-10-18 20:59:17,586 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014938}'
#  22%|██▏       | 3460/15502 [11:28<22:51,  8.78it/s]2023-10-18 20:59:17,830 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014847}'
#  22%|██▏       | 3461/15502 [11:28<22:27,  8.93it/s]2023-10-18 20:59:17,920 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000019104}'
# 2023-10-18 20:59:18,010 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014751}'
#  22%|██▏       | 3463/15502 [11:29<20:50,  9.62it/s]2023-10-18 20:59:18,101 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014742}'
#  22%|██▏       | 3465/15502 [11:29<21:33,  9.31it/s]2023-10-18 20:59:18,327 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014809}'
# 2023-10-18 20:59:18,417 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015846}'
#  22%|██▏       | 3467/15502 [11:29<20:19,  9.87it/s]2023-10-18 20:59:18,505 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015938}'
# 2023-10-18 20:59:18,594 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014554}'
#  22%|██▏       | 3469/15502 [11:29<19:30, 10.28it/s]2023-10-18 20:59:18,862 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000016511}'
#  22%|██▏       | 3471/15502 [11:29<21:51,  9.17it/s]2023-10-18 20:59:18,953 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.00001433}'
# 2023-10-18 20:59:19,040 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000016716}'
#  22%|██▏       | 3473/15502 [11:30<20:35,  9.74it/s]2023-10-18 20:59:19,246 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015042}'
#  22%|██▏       | 3475/15502 [11:30<20:36,  9.73it/s]2023-10-18 20:59:19,332 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.00001571}'
#  22%|██▏       | 3477/15502 [11:30<20:21,  9.84it/s]2023-10-18 20:59:19,531 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000025995}'
# 2023-10-18 20:59:19,617 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000025098}'
#  22%|██▏       | 3479/15502 [11:30<19:27, 10.30it/s]2023-10-18 20:59:19,845 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000021549}'
#  22%|██▏       | 3481/15502 [11:30<20:26,  9.80it/s]2023-10-18 20:59:19,935 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000021945}'
# 2023-10-18 20:59:20,025 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000023001}'
#  22%|██▏       | 3483/15502 [11:31<19:43, 10.15it/s]2023-10-18 20:59:20,261 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000022288}'
#  22%|██▏       | 3485/15502 [11:31<20:56,  9.57it/s]2023-10-18 20:59:20,352 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000022018}'
#  22%|██▏       | 3487/15502 [11:31<21:18,  9.40it/s]2023-10-18 20:59:20,574 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.00001619}'
# 2023-10-18 20:59:20,662 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000041403}'
#  23%|██▎       | 3489/15502 [11:31<20:17,  9.87it/s]2023-10-18 20:59:20,753 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000037543}'
#  23%|██▎       | 3491/15502 [11:31<21:19,  9.39it/s]2023-10-18 20:59:20,989 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014652}'
# 2023-10-18 20:59:21,077 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000016015}'
#  23%|██▎       | 3493/15502 [11:32<20:15,  9.88it/s]2023-10-18 20:59:21,166 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015994}'
#  23%|██▎       | 3495/15502 [11:32<20:42,  9.66it/s]2023-10-18 20:59:21,385 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000023226}'
# 2023-10-18 20:59:21,476 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015486}'
#  23%|██▎       | 3497/15502 [11:32<19:55, 10.04it/s]2023-10-18 20:59:21,714 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000016659}'
#  23%|██▎       | 3499/15502 [11:32<21:07,  9.47it/s]2023-10-18 20:59:21,802 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000021842}'
#  23%|██▎       | 3501/15502 [11:32<23:08,  8.64it/s]2023-10-18 20:59:22,119 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000045898}'
#  23%|██▎       | 3502/15502 [11:33<23:28,  8.52it/s]2023-10-18 20:59:22,228 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000018057}'
#  23%|██▎       | 3503/15502 [11:33<23:06,  8.65it/s]2023-10-18 20:59:22,398 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015124}'
#  23%|██▎       | 3505/15502 [11:33<26:28,  7.55it/s]2023-10-18 20:59:22,632 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015614}'
# 2023-10-18 20:59:22,723 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000033152}'
#  23%|██▎       | 3508/15502 [11:33<23:44,  8.42it/s]2023-10-18 20:59:22,995 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015578}'
#  23%|██▎       | 3509/15502 [11:33<24:47,  8.06it/s]2023-10-18 20:59:23,215 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000016684}'
#  23%|██▎       | 3510/15502 [11:34<29:44,  6.72it/s]2023-10-18 20:59:23,307 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015765}'
#  23%|██▎       | 3613/15502 [11:57<39:36,  5.00it/s]  2023-10-18 20:59:46,369 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000021735}'
#  23%|██▎       | 3615/15502 [11:57<32:55,  6.02it/s]2023-10-18 20:59:46,627 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000020626}'
#  23%|██▎       | 3617/15502 [11:57<28:47,  6.88it/s]2023-10-18 20:59:46,850 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000023214}'
#  23%|██▎       | 3619/15502 [11:57<26:39,  7.43it/s]2023-10-18 20:59:47,097 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000017164}'
#  23%|██▎       | 3621/15502 [11:58<26:30,  7.47it/s]2023-10-18 20:59:47,397 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015254}'
#  23%|██▎       | 3623/15502 [11:58<27:27,  7.21it/s]2023-10-18 20:59:47,631 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015491}'
#  23%|██▎       | 3625/15502 [11:58<25:27,  7.77it/s]2023-10-18 20:59:47,860 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015527}'
#  23%|██▎       | 3627/15502 [11:59<24:54,  7.94it/s]2023-10-18 20:59:48,104 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000018357}'
#  23%|██▎       | 3629/15502 [11:59<25:11,  7.86it/s]2023-10-18 20:59:48,363 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015386}'
#  23%|██▎       | 3631/15502 [11:59<24:58,  7.92it/s]2023-10-18 20:59:48,613 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015372}'
#  23%|██▎       | 3633/15502 [11:59<25:06,  7.88it/s]2023-10-18 20:59:48,868 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# ...
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014881}'
# 2023-10-18 21:23:24,371 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015188}'
#  97%|█████████▋| 15011/15502 [35:35<00:54,  9.04it/s]2023-10-18 21:23:24,463 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000016113}'
# 2023-10-18 21:23:24,551 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015959}'
#  97%|█████████▋| 15013/15502 [35:35<00:50,  9.71it/s]2023-10-18 21:23:24,649 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.00001439}'
# 2023-10-18 21:23:24,740 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000020202}'
#  97%|█████████▋| 15015/15502 [35:35<00:48, 10.01it/s]2023-10-18 21:23:24,830 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015189}'
# 2023-10-18 21:23:24,919 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014697}'
#  97%|█████████▋| 15017/15502 [35:35<00:46, 10.36it/s]2023-10-18 21:23:25,009 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015291}'
#  97%|█████████▋| 15019/15502 [35:36<00:50,  9.52it/s]2023-10-18 21:23:25,342 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015309}'
#  97%|█████████▋| 15020/15502 [35:36<00:57,  8.45it/s]2023-10-18 21:23:25,530 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015215}'
#  97%|█████████▋| 15021/15502 [35:36<01:04,  7.51it/s]2023-10-18 21:23:25,719 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014607}'
#  97%|█████████▋| 15022/15502 [35:36<01:10,  6.85it/s]2023-10-18 21:23:25,911 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015579}'
#  97%|█████████▋| 15023/15502 [35:36<01:15,  6.36it/s]2023-10-18 21:23:26,115 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014738}'
#  97%|█████████▋| 15024/15502 [35:37<01:21,  5.90it/s]2023-10-18 21:23:26,320 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015727}'
#  97%|█████████▋| 15025/15502 [35:37<01:25,  5.58it/s]2023-10-18 21:23:26,527 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015594}'
#  97%|█████████▋| 15026/15502 [35:37<01:29,  5.34it/s]2023-10-18 21:23:26,732 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.0000154}'
#  97%|█████████▋| 15029/15502 [35:38<01:34,  5.02it/s]2023-10-18 21:23:27,350 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000018433}'
#  97%|█████████▋| 15030/15502 [35:38<01:34,  4.98it/s]2023-10-18 21:23:28,132 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000026057}'
#  97%|█████████▋| 15031/15502 [35:39<02:55,  2.68it/s]2023-10-18 21:23:28,506 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.00002299}'
#  97%|█████████▋| 15032/15502 [35:39<02:55,  2.68it/s]2023-10-18 21:23:28,695 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000021663}'
#  97%|█████████▋| 15033/15502 [35:39<02:29,  3.14it/s]2023-10-18 21:23:28,784 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015761}'
# 2023-10-18 21:23:28,875 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000070824}'
#  97%|█████████▋| 15035/15502 [35:39<01:39,  4.69it/s]2023-10-18 21:23:28,965 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015704}'
# 2023-10-18 21:23:29,055 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000016927}'
#  97%|█████████▋| 15037/15502 [35:40<01:16,  6.08it/s]2023-10-18 21:23:29,148 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014648}'
#  97%|█████████▋| 15039/15502 [35:40<01:10,  6.54it/s]2023-10-18 21:23:29,410 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000016915}'
# 2023-10-18 21:23:29,501 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015633}'
#  97%|█████████▋| 15042/15502 [35:40<01:00,  7.63it/s]2023-10-18 21:23:29,719 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000016342}'
# 2023-10-18 21:23:29,809 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000016006}'
#  97%|█████████▋| 15045/15502 [35:40<00:55,  8.20it/s]2023-10-18 21:23:30,042 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000016086}'
# 2023-10-18 21:23:30,133 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015432}'
#  97%|█████████▋| 15066/15502 [35:45<00:59,  7.37it/s]2023-10-18 21:23:34,140 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015888}'
# 2023-10-18 21:23:34,225 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000016709}'
#  97%|█████████▋| 15068/15502 [35:45<00:49,  8.85it/s]2023-10-18 21:23:34,321 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000017175}'
# 2023-10-18 21:23:34,408 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015111}'
#  97%|█████████▋| 15070/15502 [35:45<00:45,  9.56it/s]2023-10-18 21:23:34,498 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000135342}'
# 2023-10-18 21:23:34,586 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014612}'
#  97%|█████████▋| 15072/15502 [35:45<00:42, 10.10it/s]2023-10-18 21:23:34,679 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000017378}'
# 2023-10-18 21:23:34,833 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.00001536}'
#  97%|█████████▋| 15074/15502 [35:45<00:45,  9.31it/s]2023-10-18 21:23:34,922 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000016317}'
# 2023-10-18 21:23:35,008 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000018302}'
#  97%|█████████▋| 15076/15502 [35:46<00:42,  9.91it/s]2023-10-18 21:23:35,104 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000021188}'
# 2023-10-18 21:23:35,192 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000016098}'
#  97%|█████████▋| 15078/15502 [35:46<00:41, 10.21it/s]2023-10-18 21:23:35,281 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000016099}'
# 2023-10-18 21:23:35,372 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014673}'
#  97%|█████████▋| 15080/15502 [35:46<00:40, 10.47it/s]2023-10-18 21:23:35,464 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.00001481}'
# 2023-10-18 21:23:35,559 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015655}'
#  97%|█████████▋| 15082/15502 [35:46<00:39, 10.54it/s]2023-10-18 21:23:35,650 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000016565}'
# 2023-10-18 21:23:35,740 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014672}'
#  97%|█████████▋| 15084/15502 [35:46<00:39, 10.68it/s]2023-10-18 21:23:35,828 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015546}'
# 2023-10-18 21:23:35,915 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014911}'
#  97%|█████████▋| 15086/15502 [35:46<00:38, 10.92it/s]2023-10-18 21:23:36,003 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000017449}'
#  97%|█████████▋| 15098/15502 [35:49<01:34,  4.29it/s]2023-10-18 21:23:38,792 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015705}'
#  97%|█████████▋| 15100/15502 [35:49<01:15,  5.36it/s]2023-10-18 21:23:39,054 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015984}'
# 100%|█████████▉| 15479/15502 [36:49<00:07,  3.00it/s]2023-10-18 21:24:38,307 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000016373}'
# 2023-10-18 21:24:38,395 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.00001521}'
# 100%|█████████▉| 15482/15502 [36:49<00:03,  5.11it/s]2023-10-18 21:24:38,618 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015153}'
# 2023-10-18 21:24:38,709 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000018839}'
# 100%|█████████▉| 15487/15502 [36:50<00:02,  6.70it/s]2023-10-18 21:24:39,232 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015596}'
# 2023-10-18 21:24:39,322 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000014965}'
# 100%|█████████▉| 15490/15502 [36:50<00:01,  7.98it/s]2023-10-18 21:24:39,543 - tutorial - ERROR - Error while pushing document to Qdrant: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Empty update request"},"time":0.000015614}'
# 100%|██████████| 15502/15502 [36:56<00:00,  6.99it/s]
