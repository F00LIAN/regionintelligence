# %% [markdown]
# ## Jurupa Valley Current Planning Project Scraper

# %%
import sys
sys.path.append('/Projects/regionintelligenceai/map/')

# %%
# Import libraries
import pandas as pd
import numpy as np
import requests
import json
import time
import os
import re

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

# Grab Current-Planning-Developments
link = "https://www.jurupavalley.org/336/Current-Planning-Development-Review"
df = pd.read_html(link)[0]

# %%
def set_header(df):
    """
    This function takes a dataframe as input and sets the first row as the header of the dataframe.
    """
    if df.empty:
        raise ValueError('Dataframe is empty')
    
    new_header = df.iloc[0] #grab the first row for the header
    df = df[1:] #take the data less the header row
    df.columns = new_header #set the header row as the df header
    df.dropna(inplace=True, thresh=2)
    return df

# %%
df = set_header(df)
# Out:
# C:\Users\Julian Sotelo\AppData\Local\Temp\ipykernel_10980\720186494.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True, thresh=2)

# %%
# Rename columns
df.rename(columns={'Project Name': 'projectName', 'Address': 'address', 'Applicant': 'applicantName', 'Status': 'status'}, inplace=True)

# %%
df
# Out:
# 0                                     projectName  \
# 1             Agua Mansa Road Development Project
# 2  Rock Rose & Bayberry Place (Appaloosa Springs)
# 3                                BRE Space Center
# 5                                      Troy Court
# 6                          Shops at Jurupa Valley
# 7         Vernola Marketplace Apartments- Phase A
# 8                           Wineville Marketplace
#
# 0                                                                                                  address  \
# 1                                      Agua Mansa Road/Hall Avenue (APNS: 175210032; 175210034; 175210059)
# 2                                                                                            6501 Clay St.
# 3                                                    Iberia Street and Space Center Court (APN: 156150069)
# 5                                                                          4725, 4790, and 4795 Troy Court
# 6                                    NE corner of Pyrite and Mission (APN:171020001, 171020002, 171020025)
# 7  SW corner of Van Buren Boulevard and Rutile Street (APNS: 167330006; 167330010; 167330015; & 167110039)
# 8                                           SE corner of Wineville & Limonite (APNS:157250011 & 157250013)
#
# 0                                applicantName              status
# 1                         Carson-VA Industries            Entitled
# 2                           I.H.C. Jurupa, LLC  Under Construction
# 3              BRE Space Center Mira Loma, LLC            Entitled
# 5  Davis JCR, Troy Court Industrial Owner, LLC            Entitled
# 6                    Panorama Development, LLC  Under Construction
# 7                                          NaN            Entitled
# 8                                          NaN            Entitled

# %%
# Grab Planning Staff
link_2 = "https://www.jurupavalley.org/Directory.aspx?did=9"
df_2 = pd.read_html(link_2)[2]
df_2
# Out:
#                             Staff                                         \
#                              Name                                  Title
# 0     General Housing Inquires, .                                    NaN
# 1   General Planning Inquiries, .                                    NaN
# 2                     Perez , Joe         Community Development Director
# 3                 Guevara, Dianne  Deputy Community Development Director
# 4                    Tam, Annette                       Planning Manager
# 5                Aquino, Reynaldo                         Senior Planner
# 6                 Del Rio, Miguel                      Associate Planner
# 7                  Estrada, Oscar                    Planning Technician
# 8               Gonzalez, Roberto                         Senior Planner
# 9                   Huerta, Jesus                      Associate Planner
# 10                 Lua, Christian                        Planning Intern
# 11                   Raza, Kumail                         Senior Planner
# 12                 Soriano, Erika    Administrative Services Coordinator
# 13                Torres, Jaclynn            Administrative Assistant II
# 14                  Vidal, Andrew                      Assistant Planner
#
#                                                                                                                                                                                                         \
#                                                                                                                                                                                                  Email
# 0       <!-- var w = "housinginfo"; var x = "jurupavalley.org"; var y = "housinginfo" + '@' + "jurupavalley.org"; var z = document.write("<a href=\"mailto:" + w + '@' + x + '\">' + y +'</a>'); //-->
# 1   <!-- var w = "planninginfo"; var x = "jurupavalley.org "; var y = "planninginfo" + '@' + "jurupavalley.org "; var z = document.write("<a href=\"mailto:" + w + '@' + x + '\">' + y +'</a>'); //-->
# 2                 <!-- var w = "jperez"; var x = "jurupavalley.org"; var y = "jperez" + '@' + "jurupavalley.org"; var z = document.write("<a href=\"mailto:" + w + '@' + x + '\">' + y +'</a>'); //-->
# 3           <!-- var w = "dguevara"; var x = "jurupavalley.org "; var y = "dguevara" + '@' + "jurupavalley.org "; var z = document.write("<a href=\"mailto:" + w + '@' + x + '\">' + y +'</a>'); //-->
# 4                     <!-- var w = "atam"; var x = "jurupavalley.org"; var y = "atam" + '@' + "jurupavalley.org"; var z = document.write("<a href=\"mailto:" + w + '@' + x + '\">' + y +'</a>'); //-->
# 5               <!-- var w = "raquino"; var x = "jurupavalley.org"; var y = "raquino" + '@' + "jurupavalley.org"; var z = document.write("<a href=\"mailto:" + w + '@' + x + '\">' + y +'</a>'); //-->
# 6               <!-- var w = "mdelrio"; var x = "jurupavalley.org"; var y = "mdelrio" + '@' + "jurupavalley.org"; var z = document.write("<a href=\"mailto:" + w + '@' + x + '\">' + y +'</a>'); //-->
# 7           <!-- var w = "osestrada"; var x = "jurupavalley.org"; var y = "osestrada" + '@' + "jurupavalley.org"; var z = document.write("<a href=\"mailto:" + w + '@' + x + '\">' + y +'</a>'); //-->
# 8           <!-- var w = "rgonzalez"; var x = "jurupavalley.org"; var y = "rgonzalez" + '@' + "jurupavalley.org"; var z = document.write("<a href=\"mailto:" + w + '@' + x + '\">' + y +'</a>'); //-->
# 9               <!-- var w = "jhuerta"; var x = "jurupavalley.org"; var y = "jhuerta" + '@' + "jurupavalley.org"; var z = document.write("<a href=\"mailto:" + w + '@' + x + '\">' + y +'</a>'); //-->
# 10                    <!-- var w = "clua"; var x = "jurupavalley.org"; var y = "clua" + '@' + "jurupavalley.org"; var z = document.write("<a href=\"mailto:" + w + '@' + x + '\">' + y +'</a>'); //-->
# 11                  <!-- var w = "Kraza"; var x = "jurupavalley.org"; var y = "Kraza" + '@' + "jurupavalley.org"; var z = document.write("<a href=\"mailto:" + w + '@' + x + '\">' + y +'</a>'); //-->
# 12            <!-- var w = "esoriano"; var x = "jurupavalley.org"; var y = "esoriano" + '@' + "jurupavalley.org"; var z = document.write("<a href=\"mailto:" + w + '@' + x + '\">' + y +'</a>'); //-->
# 13              <!-- var w = "jtorres"; var x = "jurupavalley.org"; var y = "jtorres" + '@' + "jurupavalley.org"; var z = document.write("<a href=\"mailto:" + w + '@' + x + '\">' + y +'</a>'); //-->
# 14                <!-- var w = "avidal"; var x = "jurupavalley.org"; var y = "avidal" + '@' + "jurupavalley.org"; var z = document.write("<a href=\"mailto:" + w + '@' + x + '\">' + y +'</a>'); //-->
#
#
#                       Phone Unnamed: 4_level_1
# 0                       NaN                NaN
# 1                       NaN                NaN
# 2   (951) 332-6464 Ext. 207                NaN
# 3   (951) 332-6464 Ext. 203                NaN
# 4   (951) 332-6464 Ext. 216                NaN
# 5   (951) 332-6464 Ext. 217                NaN
# 6   (951) 332-6464 Ext. 222                NaN
# 7   (951) 332-6464 Ext. 150                NaN
# 8   (951) 332-6464 Ext. 149                NaN
# 9       (951) 332-6464 x128                NaN
# 10  (951) 332-6464 Ext. 137                NaN
# 11  (951) 332-6464 Ext. 252                NaN
# 12  (951) 332-6464 Ext. 134                NaN
# 13   (951) 332-6464 ext 136                NaN
# 14  (951) 332-6464 Ext. 215                NaN

# %%
import pandas as pd

def clean_columns(df):
    # Dropping the 'Staff' level if it is level 0 in the MultiIndex
    df.columns = df.columns.droplevel(0)

    # Removing any columns that have 'Unnamed' in the column name
    df = df.loc[:, ~df.columns.str.contains('Unnamed')]
    df.dropna(inplace=True)

    return df

# Example usage:
# Assuming df_2 is your DataFrame with the MultiIndex as shown in your image
df= clean_columns(df)
# Out:
# C:\Users\Julian Sotelo\AppData\Local\Temp\ipykernel_10980\1563051459.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
def extract_email(js_code):
    # This pattern assumes that the variable 'y' contains the email
    pattern = re.compile(r'var y = "(.*?)" \+ \'@\' \+ "(.*?)";')
    matches = pattern.search(js_code)
    if matches:
        return matches.group(1) + '@' + matches.group(2)
    return None  # Return None or appropriate value if pattern not found

# Apply the function to the 'Email' column
df_2['Email'] = df_2['Email'].apply(extract_email)
## Rename columns
df_2.rename(columns={'Name': 'planner', 'Phone': 'phone', 'Title': 'title', 'Email': 'email'}, inplace=True)

print(df_2['Email'])
# Out:
# 2        jperez@jurupavalley.org
# 3     dguevara@jurupavalley.org
# 4          atam@jurupavalley.org
# 5       raquino@jurupavalley.org
# 6       mdelrio@jurupavalley.org
# 7     osestrada@jurupavalley.org
# 8     rgonzalez@jurupavalley.org
# 9       jhuerta@jurupavalley.org
# 10         clua@jurupavalley.org
# 11        Kraza@jurupavalley.org
# 12     esoriano@jurupavalley.org
# 13      jtorres@jurupavalley.org
# 14       avidal@jurupavalley.org
# Name: Extracted_Email, dtype: object
# C:\Users\Julian Sotelo\AppData\Local\Temp\ipykernel_10980\3700737591.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['Email'] = df_2['Email'].apply(extract_email)
